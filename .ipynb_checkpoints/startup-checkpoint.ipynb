# %% [markdown]
# ## Table Of Contents
# 1. Introduction
# 2. [Setup](setup)
#     1. [Load Audio](#loadaudio)
#     2. [Extract Sonic Features](#extractsonic)
#     3. fMRI Preprocessing
#     4. Tagging
# 3. Initial Testing
#     1. Encoding
#     2. STRF Mapping
# 4. Classification
# 5. ISC
# 6. Hemispheric Assymetry
# 7. Discussion

# %% [markdown]
# # 2. Setup <a id="setup"></a>
#
# Below, we import all the necessary libraries for the notebook and set up paths to directories that we will pull data from.

# %%
# Template from ECE480 Notebooks
import warnings
import sys

if not sys.warnoptions:
    warnings.simplefilter("ignore")
import os
import json
import glob
import numpy as np
import pandas as pd

from nilearn import datasets
from nilearn import plotting
from nilearn.input_data import NiftiMasker, NiftiLabelsMasker
from nilearn.glm.first_level import glover_hrf
import nibabel as nib

from brainiak import image, io
from brainiak.isc import isc, isfc, permutation_isc

from scipy.signal import convolve
from sklearn.preprocessing import StandardScaler

import librosa
import librosa.display

from inaSpeechSegmenter import Segmenter

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", context="notebook", font_scale=1, rc={"lines.linewidth": 2})

# %%
# Setup metadata for loading files
bids_dir = "/home/NEU480/datasets/narratives"
stimulus_dir = os.path.join(bids_dir, "stimuli")
transcripts_dir = os.path.join(stimulus_dir, "transcripts")
whisper_dir = os.path.join(stimulus_dir, "whisperx")
gentle_dir = os.path.join(stimulus_dir, "gentle/tunnel")
derivatives_dir = os.path.join(bids_dir, "derivatives")
mask_dir = os.path.join(derivatives_dir, "fmriprep")
data_dir = os.path.join(derivatives_dir, "afni-nosmooth")
audio_path = os.path.join(stimulus_dir, "tunnel_audio.wav")
dir_nilearn = "/home/NEU480/datasets/nilearn_data"

# Results path: Where the results and intermediate analyses of the tutorials are stored.
# Change this path only if you wish to save your outputs to a different folder.
scratch_directory = os.path.expanduser("/tmp/")
results_path = os.path.join(scratch_directory, "final_project_results")

# Set the location to store the data.
dir_out = f"{results_path}/"
if not os.path.exists(dir_out):
    os.makedirs(dir_out)
    print(f"Dir {dir_out} created.")
else:
    print(f"Dir {dir_out} exists.")
# Out:
# Dir /tmp/final_project_results/ exists.

# %% [markdown]
# ## 2A. Load Audio <a id="loadaudio"></a>
#
# We use the `librosa` library to load the Tunnels Under the World audio. It decodes the file and returns a time-series of floats (using the default sampling rate of 22.05 Hz). This usually does not take too long.

# %%
import time

start_time = time.perf_counter()

# Load audio (sr=None preserves native sampling rate, or set to 22050 (22.05 Hz) for standard processing)
y, sr = librosa.load(audio_path)

end_time = time.perf_counter()

print(f"Loaded {audio_path}")
print(f"Duration: {librosa.get_duration(y=y, sr=sr):.2f} seconds")
print(f"Native SR: {sr}")
print(f"Time to load: {end_time - start_time:.2f} seconds")
# Out:
# Loaded /home/NEU480/datasets/narratives/stimuli/tunnel_audio.wav
# Duration: 1533.77 seconds
# Native SR: 22050
# Time to load: 17.23 seconds

# %% [markdown]
# ## 2B. Extract Sonic Features <a id="extractsonic"></a>
#
# We begin by extracting **sound energy root mean squared** and **spectral flux**. The former measures the effective amplitude of the sound signal, i.e. its power or loudness, by calculating the root of the mean of adjacent instantaneous values, squared. The latter detects how quickly a signal's power spectrum changes over time, thereby capturing when sounds are onset and with what strength.

# %%
# 1. Sound Energy (Root Mean Square)
rms = librosa.feature.rms(y=y)[0]

# 2. Spectral Flux (Onset Strength)
# This captures the change in the power spectrum over time 
spectral_flux = librosa.onset.onset_strength(y=y, sr=sr)

# Times for each frame
frames = range(len(rms))
t = librosa.frames_to_time(frames, sr=sr)

# Create a basic dataframe for these temporal features
energy_df = pd.DataFrame({
    'time': t,
    'rms_energy': rms,
    'spectral_flux': spectral_flux
})

# %%
energy_df.head(10)
# Out:
#       time  rms_energy  spectral_flux
# 0  0.00000    0.001695       0.000000
# 1  0.02322    0.001705       0.000000
# 2  0.04644    0.001722       0.000000
# 3  0.06966    0.001150       0.121475
# 4  0.09288    0.021806       0.017866
# 5  0.11610    0.054559       0.130707
# 6  0.13932    0.067246       4.359818
# 7  0.16254    0.087558       9.529262
# 8  0.18576    0.114422       4.745287
# 9  0.20898    0.137655       1.467012

# %% [markdown]
# Some other features we are looking at include **spectral centroids** and **Mel-Frequency Cepstral Coefficients (MFCCs)**, which inform our understanding of the audio's spectral structure. The centroids, per their name, indicate where most of the sound's energy is concentrated within its spectrum and measures the perceived "brightness" or "timbre" of the sound. MFCCs attempt to mimic how ears perceive sound (and therefore how the cortical region integrates diverse sonic structures) across 13 variables, where the first captures sonic energy, 2-4 the broad shape of the spectru, and 5-13 various finer details from harmonies to consonants.

# %%
# 3. Spectral Centroid (The "center of mass" of the spectrum)
spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)[0]

# 4. MFCCs (13 coefficients is standard for capturing timbral characteristics)
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

# Add to a spectral dataframe
spectral_cols = {f'mfcc_{i+1}': mfccs[i] for i in range(13)}
spectral_cols['spectral_centroid'] = spectral_centroid
spectral_df = pd.DataFrame(spectral_cols)
spectral_df['time'] = t

# %% [markdown]
# Lastly, we also extract **pitch**, important for both speech and music. We take the fundamental frequency from the audio, which will be used later for aligning with neural data from regions that may selectively respond to pitch.

# %% [markdown]
# <div class="alert alert-warning">Note: This steps tends to take ~10 minutes to complete.</div>

# %%
# 5. Fundamental Frequency (F0) using Yin or Probabilistic Yin
begin_time = time.perf_counter()

f0, voiced_flag, voiced_probs = librosa.pyin(y, fmin=librosa.note_to_hz('C2'), 
                                            fmax=librosa.note_to_hz('C7'))
end_time = time.perf_counter()
print(f"Time to load: {end_time - start_time:.2f} seconds")

# Replace NaNs (unvoiced segments) with 0 for the time series
f0_cleaned = np.nan_to_num(f0)

pitch_df = pd.DataFrame({
    'time': t,
    'fundamental_frequency': f0_cleaned
})
# Out:
# Time to load: 586.32 seconds

# %% [markdown]
# Now, we combine and time-align everything by converting from real time to TRs, using the dataset-proposed TR of 1.5. For the potentially multiple frames that fall within a single TR, we take their mean.

# %%
TR = 1.5  

# Combine all features
all_features = pd.concat([energy_df, spectral_df.drop(columns='time'), pitch_df.drop(columns='time')], axis=1)

# Resample to match TR
all_features['tr_index'] = (all_features['time'] / TR).astype(int)
binned_features = all_features.groupby('tr_index').mean().reset_index()
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# <div class="alert alert-warning">TODOS!!!!</div>
#
# START HERE TOMORROW. GET RID OF THE TEMPORAL PADDING. JUST KEEP THE CONVOLUTION PLOT WHERE WE SHOW THAT SHIFTING 1 TR BACKWARDS IS HELPFUL FOR GETTING MAX RESULTS.
#
# MOVE INITIAL RESULTS TO NEXT SECTION, AWAY FROM PREPROCESSING.
#
# THEN KEEP WRITING UP AS U GO.
#
# THEN DO VERY QUICK (5 min max) REVIEW OF SEGMENTER LABELS AND THE FINAL DATAFRAME.
#
# THEN CLASSIFICATION!!
# THEN ISC!!
# THEN HEMISPHERE!!
#
# remember to clean up code as you go. nothing can be left to last second.
#
# WRITE UP INTRODUCTION. BRIEF METHODS. DISCUSSION!!

# %%
# The human ear perceives loudness logarithmically. We convert the linear RMS 
# energy into a decibel (dB) scale to better represent auditory perception.
# We add a tiny constant (1e-6) to avoid log(0) warnings for pure silence.

binned_features['rms_energy_db'] = 20 * np.log10(binned_features['rms_energy'] + 1e-6)

# We can drop the original linear RMS energy to avoid redundant features in the model
binned_features = binned_features.drop(columns=['rms_energy'])

# %%
# ---------------------------------------------------------
# Step 2: HRF Convolution
# ---------------------------------------------------------
# The BOLD fMRI signal peaks ~5-6 seconds after the neural event. 
# We convolve our acoustic features with a standard HRF (Glover model) 
# to simulate how these sound features would theoretically look in the brain.

# Generate the HRF kernel for our specific TR
hrf_kernel = glover_hrf(t_r=TR, oversampling=1)

# List of columns to convolve (everything except the TR index/time tracking columns)
features_to_convolve = [col for col in binned_features.columns if col not in ['tr_index', 'time']]

# Create a new DataFrame to hold the convolved features
convolved_features = binned_features.copy()

for feature in features_to_convolve:
    # Convolve the feature with the HRF
    convolved_signal = convolve(binned_features[feature].values, hrf_kernel, mode='full')
    
    # The convolution output is longer than the input. We slice it to match 
    # the original number of TRs (keeping the delay intact).
    convolved_features[feature] = convolved_signal[:len(binned_features)]

# %%
# ---------------------------------------------------------
# Step 3: Z-Scoring (Standardization)
# ---------------------------------------------------------
# Features like F0 (measured in Hz) and Energy (measured in dB) have vastly 
# different scales. Z-scoring (mean=0, std=1) ensures that Ridge Regression 
# doesn't unfairly weight features simply because they have larger raw numerical values.

scaler = StandardScaler()

# We scale the convolved features
convolved_features[features_to_convolve] = scaler.fit_transform(convolved_features[features_to_convolve])

# %%
# ---------------------------------------------------------
# Step 4: Temporal Padding & Alignment
# ---------------------------------------------------------
# Based on the dataset metadata:
# - Functional scans are 1040 TRs.
# - Stimulus starts after 2 TRs (3 seconds).

TARGET_TRS = 1040
DELAY_TRS = 2

# We only want to pad the actual acoustic features, not the tr_index or time columns
feature_cols = [col for col in convolved_features.columns if col not in ['tr_index', 'time']]

# 1. Create the padding for the beginning (Scanner running, no audio yet)
# We use 0 because the data is Z-scored (0 represents the mean/baseline)
start_padding = pd.DataFrame(0, index=range(DELAY_TRS), columns=feature_cols)

# 2. Append the convolved features
aligned_features = pd.concat([start_padding, convolved_features[feature_cols]], ignore_index=True)

# 3. Create the padding for the end (Audio finished, scanner still running)
current_length = len(aligned_features)
if current_length < TARGET_TRS:
    end_padding_length = TARGET_TRS - current_length
    end_padding = pd.DataFrame(0, index=range(end_padding_length), columns=feature_cols)
    aligned_features = pd.concat([aligned_features, end_padding], ignore_index=True)
elif current_length > TARGET_TRS:
    # If for some reason the audio extraction ran slightly long, truncate it
    aligned_features = aligned_features.iloc[:TARGET_TRS]

# Re-add a clean TR index for the final matrix
aligned_features.insert(0, 'tr_index', range(TARGET_TRS))

# %%
aligned_features.head(50)
# Out:
#     tr_index  spectral_flux    mfcc_1    mfcc_2    mfcc_3    mfcc_4    mfcc_5  \
# 0          0       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1          1       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2          2      -2.567714  5.447419 -2.460578 -0.345109 -0.459899 -0.190025
# 3          3      -2.567714  5.447419 -2.460578 -0.345109 -0.459899 -0.190025
# 4          4      -2.339904  5.226442 -2.321767 -0.362983 -0.420201 -0.214314
# 5          5      -0.813437  3.554457 -1.348915 -0.435439 -0.133059 -0.351590
# 6          6       0.984929  0.606426  0.055108 -0.265062  0.288447 -0.438828
# 7          7       2.211696 -1.637571  1.334630  0.000753  0.425785 -0.814104
# 8          8       2.100739 -2.587315  2.095451  0.489145  0.198886 -1.200744
# 9          9       0.660925 -2.595729  2.414766  1.444812  0.155578 -1.394456
# 10        10      -1.177895 -2.254617  2.231184  2.458494  0.718975 -1.056159
# 11        11      -2.417334 -1.869705  1.675829  2.937676  1.370559 -0.282480
# 12        12      -2.699381 -1.415111  1.167693  2.780627  1.457625  0.151243
# 13        13      -2.114718 -0.941231  0.767131  2.120463  1.113512  0.160188
# 14        14      -0.770160 -0.345628  0.631216  1.195574  0.602065  0.251007
# 15        15       0.456426  0.140791  0.639002  0.412239 -0.075848  0.281350
# 16        16       0.996675  0.316464  0.513451 -0.070715 -0.647501 -0.091156
# 17        17       1.000289  0.851714  0.672393 -0.818472 -1.191251 -0.263695
# 18        18       0.553400  1.993158  1.036930 -2.190522 -1.774396 -0.407448
# 19        19      -0.133770  2.261467  0.946264 -2.717528 -1.875821 -0.248659
# 20        20      -0.294055  1.716574  0.906310 -1.838823 -1.427828  0.208431
# 21        21      -0.152260  0.979595  1.054678 -0.275661 -0.551753  0.820505
# 22        22      -0.041704  0.230849  0.765536  0.909181  0.576387  1.186705
# 23        23       0.418515 -0.054825  0.397949  1.187290  1.392881  1.179120
# 24        24       1.040713  0.007370  0.344784  1.093430  1.515435  0.775876
# 25        25       1.226284  0.070111  0.372477  0.956289  1.221142  0.272142
# 26        26       0.751652 -0.077769  0.271086  0.913936  0.985567  0.137379
# 27        27       0.088928 -0.486903 -0.178202  0.742564  0.761326  0.284350
# 28        28      -0.467950 -1.003350 -0.992281  0.150159  0.357689  0.385143
# 29        29      -0.378448 -1.088311 -1.599363 -0.825673 -0.275610  0.083980
# 30        30       0.312923 -0.560309 -1.454097 -1.696450 -1.147954 -0.711579
# 31        31       1.098322  0.082095 -0.795266 -1.970865 -1.942666 -1.620417
# 32        32       1.420842  0.395568 -0.182818 -1.601555 -2.010621 -1.767999
# 33        33       1.295029  0.206409 -0.089471 -0.962359 -1.249729 -1.091808
# 34        34       0.526463 -0.513943 -0.551674 -0.185055 -0.223714 -0.222592
# 35        35      -0.394864 -1.183870 -0.933468  0.652769  0.776514  0.555541
# 36        36      -0.569600 -1.276377 -0.898514  1.042266  1.355493  0.909748
# 37        37      -0.141574 -0.974304 -0.726294  0.791915  1.313276  0.870233
# 38        38       0.387759 -0.566053 -0.687569  0.032585  0.802640  0.491672
# 39        39       0.403816 -0.503030 -0.912294 -0.587029  0.148224 -0.024241
# 40        40       0.552238 -0.502524 -1.029361 -0.865065 -0.229691 -0.325901
# 41        41       0.918614 -0.439878 -0.915012 -0.836069 -0.343528 -0.382886
# 42        42       0.766993 -0.541557 -0.948259 -0.664605 -0.230377 -0.410993
# 43        43      -0.180544 -1.000335 -1.281173 -0.273698  0.155084 -0.151887
# 44        44      -1.028652 -1.367702 -1.478323  0.156520  0.524004  0.265833
# 45        45      -0.740308 -1.059762 -1.046862  0.417864  0.647292 -0.001858
# 46        46      -0.014046 -0.440225 -0.346662  0.449641  0.533960 -0.360159
# 47        47       0.897271  0.177839  0.193818  0.085010  0.147420 -0.582511
# 48        48       1.623849  0.654161  0.514201 -0.487221 -0.469289 -0.688356
# 49        49       1.545665  1.035214  0.778002 -0.993224 -1.191165 -1.035537
#
#       mfcc_6    mfcc_7    mfcc_8    mfcc_9   mfcc_10   mfcc_11   mfcc_12  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.614941  1.046830  1.427411  1.318362  1.187871  1.412383  0.988322
# 3   0.614941  1.046830  1.427411  1.318361  1.187871  1.412383  0.988322
# 4   0.555246  1.061774  1.346693  1.164984  1.140494  1.346282  0.946848
# 5   0.143617  1.116803  0.789238  0.116105  0.787023  0.877272  0.623668
# 6  -0.442971  0.987155  0.061356 -1.293957  0.153276  0.175987 -0.048975
# 7  -1.069032  1.061983 -0.388576 -2.670603 -0.540146 -0.455845 -0.950922
# 8  -1.197757  1.000122 -0.505971 -3.171513 -1.113764 -0.952931 -1.872062
# 9  -1.108139  0.156017 -0.642707 -2.685244 -1.520289 -1.509299 -2.809690
# 10 -0.938304 -0.945401 -0.870033 -1.892210 -1.717295 -1.962728 -3.385746
# 11 -0.545383 -1.556121 -1.034576 -1.326399 -1.684566 -1.965154 -3.268391
# 12 -0.217774 -1.501298 -0.871490 -1.020303 -1.623575 -1.757166 -2.768646
# 13 -0.194997 -1.039062 -0.393378 -0.818028 -1.498169 -1.477924 -2.217137
# 14 -0.163708 -0.463571  0.106520 -0.644411 -1.508134 -1.303730 -1.450223
# 15  0.210305  0.008205  0.168409 -0.438602 -1.290840 -0.958066 -0.529675
# 16  0.527543  0.364952 -0.107281 -0.437478 -0.898644 -0.532866  0.052858
# 17  0.559090  0.675422 -0.211313 -0.545791 -0.747473 -0.784695 -0.229262
# 18  0.581988  1.054190  0.091804 -0.593045 -1.107712 -1.266378 -1.338227
# 19  0.871865  1.311506  0.516525 -0.474925 -1.476882 -1.571514 -2.302131
# 20  0.996180  0.975394  0.604898 -0.194920 -1.492796 -1.576386 -2.091904
# 21  0.928402  0.214167  0.409161  0.265649 -0.992511 -1.110944 -1.024340
# 22  0.854306 -0.224720  0.133478  0.493156 -0.400163 -0.576311 -0.061011
# 23  0.705110 -0.424528 -0.310082  0.560242 -0.234685 -0.337205  0.472424
# 24  0.536782 -0.597373 -0.763020  0.655510 -0.439618 -0.456944  0.590352
# 25  0.490059 -0.657020 -1.153361  0.543302 -0.703852 -0.664967  0.502137
# 26  0.444559 -0.477853 -1.073856  0.017575 -1.063343 -0.679150  0.470828
# 27  0.471584 -0.010743 -0.382219 -0.162360 -0.938257 -0.257968  0.447017
# 28  0.380830  0.417407  0.444247  0.157535 -0.112411  0.470191  0.407071
# 29 -0.042286  0.333079  0.819633  0.455508  0.681085  1.197722  0.321346
# 30 -0.810046 -0.219385  0.622451  0.087867  0.627640  1.402513  0.107012
# 31 -1.455217 -0.638195  0.113836 -0.874448 -0.289599  0.731217 -0.195301
# 32 -1.526285 -0.745664 -0.421305 -1.747222 -1.351986 -0.555877 -0.563173
# 33 -1.182081 -0.749562 -0.798654 -2.099051 -2.025897 -1.530884 -0.841251
# 34 -0.540841 -0.434853 -0.513240 -1.528172 -1.810243 -1.512126 -0.775501
# 35  0.178052  0.106038  0.256934 -0.406993 -1.112791 -0.880261 -0.420919
# 36  0.381391  0.448152  0.863976  0.218102 -0.806288 -0.384901 -0.152751
# 37  0.205366  0.329277  0.751180  0.342718 -0.658860 -0.278031 -0.054087
# 38 -0.133344  0.062674  0.305448  0.341741 -0.514550 -0.312984 -0.142936
# 39 -0.270050  0.190608  0.288345  0.425158 -0.231137 -0.071778 -0.137530
# 40 -0.454696  0.064296  0.233871  0.031054 -0.501821  0.104381 -0.096797
# 41 -0.731429 -0.452811  0.046019 -0.613596 -1.204107  0.017184 -0.256726
# 42 -0.730442 -0.534627  0.075568 -0.636089 -1.357909 -0.024365 -0.383117
# 43 -0.122031  0.191912  0.476565 -0.022882 -0.645752  0.080340 -0.386362
# 44  0.736052  1.088421  0.686248  0.330839  0.125984  0.170945 -0.279019
# 45  1.066423  1.805598  0.446887 -0.231773  0.149953  0.036448 -0.190943
# 46  0.794448  1.874175  0.228389 -1.048434 -0.573483 -0.276093 -0.052655
# 47  0.113120  1.036699 -0.232202 -1.597499 -1.461833 -0.399975  0.360095
# 48 -0.596774 -0.251862 -0.922998 -1.820066 -1.985398 -0.403147  0.804887
# 49 -1.337491 -1.297026 -1.386021 -1.913366 -2.039028 -0.568137  0.822915
#
#      mfcc_13  spectral_centroid  fundamental_frequency  rms_energy_db
# 0   0.000000           0.000000               0.000000       0.000000
# 1   0.000000           0.000000               0.000000       0.000000
# 2   1.248519          -2.115033              -0.804111       3.240207
# 3   1.248518          -2.115033              -0.804111       3.240207
# 4   1.203454          -1.998327              -0.768706       3.114340
# 5   0.872138          -1.143908              -0.527863       2.171421
# 6   0.323254           0.214928              -0.224961       0.566462
# 7  -0.217589           1.113554               0.011886      -0.520028
# 8  -1.067043           1.209584               0.210107      -0.605645
# 9  -2.383818           0.445236               0.518077      -0.048891
# 10 -3.437488          -0.710715               0.907228       0.433502
# 11 -3.693616          -1.609513               1.204137       0.635785
# 12 -3.313095          -1.984620               1.306463       0.755861
# 13 -2.560223          -1.832970               1.142219       0.741688
# 14 -1.572230          -1.439415               0.644573       0.595138
# 15 -0.570613          -1.026512               0.071244       0.320080
# 16 -0.008614          -0.548471              -0.447350       0.055292
# 17 -0.041417          -0.168470              -0.846726       0.208490
# 18 -0.733594           0.133982              -0.609473       0.719566
# 19 -1.429885           0.182272               0.032108       0.786302
# 20 -1.441380          -0.222100               0.358122       0.682695
# 21 -0.873902          -0.808273               0.217786       0.652115
# 22 -0.437882          -0.968335               0.062181       0.670688
# 23 -0.518380          -0.771657              -0.050265       0.787073
# 24 -0.796379          -0.607635              -0.197330       0.798965
# 25 -0.811046          -0.471904              -0.385737       0.581914
# 26 -0.528981          -0.454527              -0.484471       0.231986
# 27 -0.236445          -0.133122              -0.418801      -0.240960
# 28  0.261588           0.905512              -0.220811      -0.604784
# 29  0.768683           1.932308              -0.065664      -0.576592
# 30  0.904955           2.001204               0.084817      -0.253715
# 31  0.612213           1.197410               0.436169       0.153971
# 32  0.391122           0.161663               0.905062       0.392330
# 33  0.118254          -0.429178               1.276091       0.323384
# 34 -0.024720          -0.116064               1.038736      -0.225680
# 35 -0.108890           0.328275               0.362405      -0.818034
# 36 -0.376268           0.361053              -0.091411      -0.873585
# 37 -0.608605           0.346866              -0.153058      -0.588444
# 38 -0.888489           0.575200               0.106302      -0.221833
# 39 -0.939293           1.158418               0.275613      -0.147247
# 40 -0.960961           1.274694               0.503114      -0.091051
# 41 -1.053821           0.734851               0.816453       0.055044
# 42 -0.982837           0.523395               0.799667      -0.008738
# 43 -0.512934           1.079060               0.316129      -0.628692
# 44  0.093745           1.828375              -0.275217      -1.123723
# 45  0.420504           1.826998              -0.568300      -0.897935
# 46  0.384804           1.004367              -0.461728      -0.386396
# 47 -0.048637          -0.049560              -0.047622       0.137118
# 48 -0.344246          -0.834500               0.413364       0.581677
# 49 -0.038741          -1.153294               0.846127       1.012072

# %%
# Assuming your dataframe is named 'aligned_features' and TR = 1.5s
# Convert TR index back to minutes for a cleaner x-axis
time_in_minutes = (aligned_features['tr_index'] * TR) / 60

# Set up a sleek, multi-panel figure
fig, axes = plt.subplots(4, 1, figsize=(16, 12), sharex=True, gridspec_kw={'height_ratios': [1, 1, 1, 2]})
sns.set_theme(style="darkgrid")

# ---------------------------------------------------------
# Plot 1: Sound Energy (dB)
# ---------------------------------------------------------
axes[0].plot(time_in_minutes, aligned_features['rms_energy_db'], color='crimson', linewidth=1.5)
axes[0].set_title('Sound Energy (Loudness)', fontsize=14, fontweight='bold')
axes[0].set_ylabel('Amplitude (Z-Scored)')

# ---------------------------------------------------------
# Plot 2: Spectral Flux (Onsets)
# ---------------------------------------------------------
axes[1].plot(time_in_minutes, aligned_features['spectral_flux'], color='darkorange', linewidth=1.5)
axes[1].set_title('Spectral Flux (Acoustic Onsets / Rhythmic Changes)', fontsize=14, fontweight='bold')
axes[1].set_ylabel('Flux (Z-Scored)')

# ---------------------------------------------------------
# Plot 3: Pitch & Spectral Centroid
# ---------------------------------------------------------
axes[2].plot(time_in_minutes, aligned_features['spectral_centroid'], color='dodgerblue', label='Centroid (Brightness)', alpha=0.8)
axes[2].plot(time_in_minutes, aligned_features['fundamental_frequency'], color='mediumpurple', label='Pitch (F0)', alpha=0.8)
axes[2].set_title('Tonal Quality: Pitch vs. Brightness', fontsize=14, fontweight='bold')
axes[2].set_ylabel('Frequency (Z-Scored)')
axes[2].legend(loc='upper right')

# ---------------------------------------------------------
# Plot 4: MFCC Heatmap (Timbre)
# ---------------------------------------------------------
# Extract just the MFCC columns and transpose them for the heatmap (Features on Y, Time on X)
mfcc_cols = [f'mfcc_{i}' for i in range(1, 14)]
mfcc_data = aligned_features[mfcc_cols].T

# Get the max time to bind the image to the correct axis scale
max_time = time_in_minutes.max()

# Use imshow to draw the heatmap, bound strictly to the time_in_minutes scale
im = axes[3].imshow(mfcc_data, aspect='auto', cmap='magma', origin='lower',
                    extent=[0, max_time, 0, 13])
axes[3].set_title('MFCCs 1-13 (Spectral Texture & Timbre)', fontsize=14, fontweight='bold')
axes[3].set_ylabel('Coefficients')
axes[3].set_xlabel('Time (Minutes)', fontsize=12)

# Set the y-ticks to match the 13 coefficients
axes[3].set_yticks(np.arange(0.5, 13.5, 1))
axes[3].set_yticklabels(range(1, 14))

# Add the colorbar bound specifically to this axis
fig.colorbar(im, ax=axes[3], orientation='horizontal')#, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()

# %% [markdown]
# # NEURO

# %%
# Set up atlas to pull out Heschl's Gyrus (primary auditory cortex, A1) and Superior Temporal Gyrus

# Fetch the Harvard-Oxford cortical atlas
atlas = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr25-2mm', data_dir=dir_nilearn)
atlas_filename = atlas.maps
labels = atlas.labels

# Find the indices for our target Auditory ROIs
heschls_idx = labels.index("Heschl's Gyrus (includes H1 and H2)")
stg_anterior_idx = labels.index("Superior Temporal Gyrus, anterior division")
stg_posterior_idx = labels.index("Superior Temporal Gyrus, posterior division")

print(f"Heschl's Gyrus index: {heschls_idx}")
print(f"STG Anterior index: {stg_anterior_idx}")
print(f"STF Posterior index: {stg_posterior_idx}")
# Out:
# [fetch_atlas_harvard_oxford] Dataset found in /home/NEU480/datasets/nilearn_data/fsl
# Heschl's Gyrus index: 45
# STG Anterior index: 9
# STF Posterior index: 10

# %%
# Choose subject
subj_id = "sub-005"

# 1. Setup the Masker (This handles extraction, detrending, and standardizing)
# TR = 1.5. We apply a high-pass filter (0.01 Hz) to remove slow scanner drift.
masker = NiftiLabelsMasker(labels_img=atlas_filename, labels=labels, t_r=TR)

# 2. Select a valid single subject for our preliminary test
test_subject_filepath = os.path.join(data_dir, f"{subj_id}/func/{subj_id}_task-tunnel_space-MNI152NLin2009cAsym_res-native_desc-clean_bold.nii.gz")
print(f"Processing subject: {test_subject_filepath}")

# 3. Extract the time series
# This takes a minute. It fits the atlas to the subject and extracts a 2D array: (1040 TRs, Number of Atlas Regions)
time_series = masker.fit_transform(test_subject_filepath)

print(f"Extracted time series shape: {time_series.shape} (Expected: 1040 TRs, 48 Regions)")
# Out:
# Processing subject: /home/NEU480/datasets/narratives/derivatives/afni-nosmooth/sub-005/func/sub-005_task-tunnel_space-MNI152NLin2009cAsym_res-native_desc-clean_bold.nii.gz
# Extracted time series shape: (1040, 48) (Expected: 1040 TRs, 48 Regions)

# %%
# The masker drops the 'Background' label (index 0), so we must shift our label indices by -1
heschls_signal = time_series[:, heschls_idx - 1]
stg_ant_signal = time_series[:, stg_anterior_idx - 1]
stg_post_signal = time_series[:, stg_posterior_idx - 1]

# Create a composite "Auditory Network" signal by averaging them
# (Or you can just use heschls_signal for strict Primary Auditory Cortex)
auditory_signal = np.mean([heschls_signal, stg_ant_signal, stg_post_signal], axis=0)

print("Auditory signals isolated.")
# Out:
# Auditory signals isolated.

# %%
from scipy.stats import pearsonr

# Load the aligned acoustic features
# Assuming 'aligned_features' is still in memory, otherwise load the CSV:
# aligned_features = pd.read_csv(os.path.join(dir_out, "acoustic_features_aligned_1040TR.csv"))

sound_energy = aligned_features['rms_energy_db'].values

# Calculate Pearson correlation
r_value, p_value = pearsonr(sound_energy, heschls_signal)

print(f"Correlation (r): {r_value:.4f}")
print(f"P-value (p): {p_value:.4e}")

# Visualization: Scatter plot with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x=sound_energy, y=heschls_signal, scatter_kws={'alpha':0.3, 'color':'#4C72B0'}, line_kws={'color':'#C44E52'})
plt.title(f"Auditory Cortex Activity vs. Sound Energy\nSubject: {os.path.basename(test_subject_filepath)[:7]} | $r = {r_value:.3f}$, p = {p_value:.3f}", fontsize=14)
plt.xlabel("Convolved Sound Energy (Z-Scored dB)", fontsize=12)
plt.ylabel("Auditory Cortex BOLD Signal (Z-Scored)", fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Correlation (r): 0.4807
# P-value (p): 3.0273e-61

# %%
# 1. Test purely Heschl's Gyrus (A1)
r_val_a1, p_val_a1 = pearsonr(sound_energy, heschls_signal)
print(f"Pure A1 Correlation: r={r_val_a1:.4f}, p={p_val_a1:.4e}")

# 2. Cross-Correlation (Lag Plot) to check alignment
lags = np.arange(-10, 11) # Check +/- 10 TRs (15 seconds)
cross_corr = [pearsonr(np.roll(sound_energy, lag), heschls_signal)[0] for lag in lags]

plt.figure(figsize=(8, 4))
plt.stem(lags, cross_corr)
plt.title("Cross-Correlation: Sound Energy vs. A1")
plt.xlabel("Lag (TRs)")
plt.ylabel("Pearson r")
plt.axvline(0, color='r', linestyle='--', alpha=0.5)
plt.show()
# Out:
# Pure A1 Correlation: r=-0.0123, p=6.9092e-01

# %%
# ---------------------------------------------------------
# Corrected Temporal Padding & Alignment
# ---------------------------------------------------------
TARGET_TRS = 1040

# We only want to pad the actual acoustic features
feature_cols = [col for col in convolved_features.columns if col not in ['tr_index', 'time']]

# 1. Start directly with the convolved features (No initial silence padding)
aligned_features = convolved_features[feature_cols].copy()
aligned_features[feature_cols] = aligned_features[feature_cols].shift(-1, fill_value=0)

# 3. Save the perfectly empirically-aligned matrix
final_aligned_path = os.path.join(dir_out, "acoustic_features_aligned_1040TR.csv")
aligned_features.to_csv(final_aligned_path, index=False)

print("Matrix shifted by -1 TR to correct for HRF/preprocessing lag.")

# 2. Pad the end (Audio finished, scanner still running)
current_length = len(aligned_features)
if current_length < TARGET_TRS:
    end_padding_length = TARGET_TRS - current_length
    end_padding = pd.DataFrame(0, index=range(end_padding_length), columns=feature_cols)
    aligned_features = pd.concat([aligned_features, end_padding], ignore_index=True)
elif current_length > TARGET_TRS:
    # Truncate if it slightly overshoots
    aligned_features = aligned_features.iloc[:TARGET_TRS]

# 3. Re-add a clean TR index for the final matrix
aligned_features.insert(0, 'tr_index', range(TARGET_TRS))

# Save the properly aligned matrix to overwrite the old one
final_aligned_path = os.path.join(dir_out, "acoustic_features_aligned_1040TR.csv")
aligned_features.to_csv(final_aligned_path, index=False)

print(f"Alignment corrected. Matrix shape is now: {aligned_features.shape}")
# Out:
# Matrix shifted by -1 TR to correct for HRF/preprocessing lag.
# Alignment corrected. Matrix shape is now: (1040, 18)

# %%
# Load the corrected feature matrix
sound_energy = aligned_features['rms_energy_db'].values

# Calculate Pearson correlation with pure A1 signal
r_val, p_val = pearsonr(sound_energy, heschls_signal)

print(f"Corrected A1 Correlation: r={r_val:.4f}, p={p_val:.4e}")

# Visualization: Scatter plot with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x=sound_energy, y=heschls_signal, scatter_kws={'alpha':0.3, 'color':'#4C72B0'}, line_kws={'color':'#C44E52'})
plt.title(f"Heschl's Gyrus Activity vs. Sound Energy\nSubject: {os.path.basename(test_subject_filepath)[:7]} | $r = {r_val:.5f}$, p = {p_val:.3f}", fontsize=14)
plt.xlabel("Convolved Sound Energy (Z-Scored dB)", fontsize=12)
plt.ylabel("Auditory Cortex BOLD Signal (Z-Scored)", fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Corrected A1 Correlation: r=0.4807, p=3.0273e-61

# %%
from scipy.signal import find_peaks

# Assuming 'aligned_features' is loaded and time_in_minutes is defined
time_in_minutes = (aligned_features['tr_index'] * 1.5) / 60
flux_signal = aligned_features['spectral_flux'].values

# Find the peaks (onsets) in the flux signal
# height=1.0 means we only care about peaks that are at least 1 standard deviation above the mean
# distance=2 ensures we don't pick up multiple peaks within 3 seconds (2 TRs) of each other
peaks, properties = find_peaks(flux_signal, height=1.0, distance=2)

# Set up the visualization
plt.figure(figsize=(14, 5))
sns.set_theme(style="darkgrid")

# Plot the continuous flux signal
plt.plot(time_in_minutes, flux_signal, color='darkorange', linewidth=1.5, label='Spectral Flux')

# Overlay the detected peaks as red dots
plt.plot(time_in_minutes[peaks], flux_signal[peaks], "ro", markersize=6, label='Major Onsets (Rhythmic Spikes)')

# Formatting
plt.title('Spectral Flux: Detecting Acoustic Onsets Over Time', fontsize=16, fontweight='bold')
plt.xlabel('Time (Minutes)', fontsize=12)
plt.ylabel('Flux Magnitude (Z-Scored)', fontsize=12)

# Highlight a specific highly-active window (e.g., minutes 5 to 10) to show detail
plt.axvspan(12.5, 14, color='gray', alpha=0.1, label='Example Active Window')

plt.legend(loc='upper right')
plt.xlim(0, time_in_minutes.max())
plt.tight_layout()
plt.show()

# %%
# 1. Extract the Spectral Flux signal from your correctly aligned matrix
flux_signal = aligned_features['spectral_flux'].values

# 2. Direct Pearson correlation at Lag 0 (Perfectly aligned TRs)
r_val_flux, p_val_flux = pearsonr(flux_signal, heschls_signal)
print(f"A1 Correlation with Spectral Flux (Lag 0): r={r_val_flux:.4f}, p={p_val_flux:.4e}")

# 3. Cross-Correlation (Lag Plot) to check the temporal profile
lags = np.arange(-10, 11) # Check +/- 10 TRs (15 seconds)
cross_corr_flux = [pearsonr(np.roll(flux_signal, lag), heschls_signal)[0] for lag in lags]

# Find the peak lag automatically
peak_lag_idx = np.argmax(cross_corr_flux)
peak_lag = lags[peak_lag_idx]
peak_r = cross_corr_flux[peak_lag_idx]

# 4. Visualization
plt.figure(figsize=(10, 5))
plt.stem(lags, cross_corr_flux, basefmt=" ")
plt.title("Cross-Correlation: Spectral Flux vs. Heschl's Gyrus (A1)", fontsize=14, fontweight='bold')
plt.xlabel("Lag (TRs) [1 TR = 1.5s]", fontsize=12)
plt.ylabel("Pearson r", fontsize=12)

# Add reference lines and highlight the peak
plt.axvline(0, color='red', linestyle='--', alpha=0.5, label="Lag 0 (Aligned)")
plt.plot(peak_lag, peak_r, 'go', markersize=10, label=f"Peak: Lag {peak_lag} (r={peak_r:.3f})")

plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# A1 Correlation with Spectral Flux (Lag 0): r=0.3262, p=3.3193e-27

# %%
# 1. Extract the newly aligned Spectral Flux signal
flux_signal = aligned_features['spectral_flux'].values

# 2. Calculate the overall Pearson correlation
r_val_flux, p_val_flux = pearsonr(flux_signal, heschls_signal)

print(f"Overall A1 Correlation with Spectral Flux: r={r_val_flux:.4f}, p={p_val_flux:.4e}")

# 3. Visualization: Scatter plot with regression line
plt.figure(figsize=(8, 6))

# Using an orange/purple color scheme to differentiate from the Sound Energy plot
sns.regplot(x=flux_signal, y=heschls_signal, 
            scatter_kws={'alpha':0.3, 'color':'darkorange'}, 
            line_kws={'color':'purple', 'linewidth': 2})

plt.title(f"Heschl's Gyrus Activity vs. Spectral Flux\nSubject: {os.path.basename(test_subject_filepath)[:7]} | $r = {r_val_flux:.3f}$", fontsize=14, fontweight='bold')
plt.xlabel("Convolved Spectral Flux (Z-Scored)", fontsize=12)
plt.ylabel("Heschl's Gyrus BOLD Signal (Z-Scored)", fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Overall A1 Correlation with Spectral Flux: r=0.4125, p=5.5105e-44

# %%
# CONTROL GROUP

control_idx = labels.index("Occipital Fusiform Gyrus")
control_signal = time_series[:, control_idx - 1]

# Load the corrected feature matrix
sound_energy = aligned_features['rms_energy_db'].values

# Calculate Pearson correlation with pure A1 signal
r_val, p_val = pearsonr(sound_energy, control_signal)

print(f"Corrected A1 Correlation: r={r_val:.4f}, p={p_val:.4e}")

# Visualization: Scatter plot with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x=sound_energy, y=control_signal, scatter_kws={'alpha':0.3, 'color':'#4C72B0'}, line_kws={'color':'#C44E52'})
plt.title(f"Occipital Fusiform Gyrus Activity vs. Sound Energy\nSubject: {os.path.basename(test_subject_filepath)[:7]} | $r = {r_val:.5f}$, p = {p_val:.3f}", fontsize=14)
plt.xlabel("Convolved Sound Energy (Z-Scored dB)", fontsize=12)
plt.ylabel("Visual Cortex Activity (Z-Scored)", fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Corrected A1 Correlation: r=-0.0014, p=9.6361e-01

# %% [markdown]
# ### Tagging
# As our last step of preprocessing, we want to enable experimental analysis on our "speech" vs. "music" hypothesis. This means we have to tag the audio with TR-aligned labels that correctly represent speech, music, both, or noise.
#
# A hybrid approach will be used:
# 1. inaSpeechSegmenter - a convolutional neural network-based toolkit that splits audio into speech, music, and noise. It outputs a table in the format (label, start, end), where the latter two fields are in seconds. However, this does not natively output a 'both speech & music' label.
# 2. Gentle - a time-aligned transcript with word-level start and end labels. This can capture speech labeling.
#
# So, a 'both speech & music' label can be created by overlapping the two outputs.

# %% [markdown]
# <div class="alert alert-warning">
# Note: Segmenter() fails to run on Adroit because it does not come installed with its neural network weights to save space and attempts to download it from a URL. Since Adroit is offline, open a login node that has internet access and paste the following line to cache the weights in your home directory:
#
# ```python
# python -c "from inaSpeechSegmenter import Segmenter; Segmenter()"
# ```
# This also takes quite a while (~20 min) to run.
# <\div>

# %%
# Initialize the segmenter (this will download the pre-trained weights the first time)
seg = Segmenter()

# Run the segmentation on your audio file
audio_path = os.path.join(stimulus_dir, "tunnel_audio.wav")
segmentation = seg(audio_path)

# Convert to a DataFrame for easy viewing
seg_df = pd.DataFrame(segmentation, columns=['label', 'start', 'end'])
print(seg_df.head())

# Filter purely for the music tags
music_tags = seg_df[seg_df['label'] == 'music']
print(music_tags.head())
# Out:
# 1997/1997 - 36s - 18ms/step
# 1596/1596 - 157s - 98ms/step
#       label  start    end
# 0      male   0.00   2.42
# 1  noEnergy   2.42   3.20
# 2      male   3.20   4.80
# 3  noEnergy   4.80   5.38
# 4     music   5.38  13.02
#     label   start     end
# 4   music    5.38   13.02
# 29  music   66.82   78.54
# 43  music  121.92  124.94
# 45  music  134.10  135.58
# 86  music  209.00  215.34

# %% [markdown]
# Gentle transcripts have a specific JSON format that we will parse now. Additionally, as the dataset metadata mentioned 126 unsuccessfully localized words, this will also show in the transcript, specifically in the `case` field as `not-found-in-audio`. Looping through every word looking for the `start` and `end` fields will throw a key error for those words, so we begin by filtering them out.

# %%
import json

# Load Gentle JSON file
gentle_filepath = os.path.join(gentle_dir, "align.json")
with open(gentle_filepath, 'r') as f:
    gentle_data = json.load(f)

# Extract and filter words, 'success' only
valid_speech_words = [
    word for word in gentle_data['words'] 
    if word.get('case') == 'success' and 'start' in word and 'end' in word
]

print(f"Total words: {len(gentle_data['words'])}")
print(f"Successfully aligned speech blocks: {len(valid_speech_words)}")
# Out:
# Total words: 3435
# Successfully aligned speech blocks: 3309

# %% [markdown]
# Now we can align the inaSpeechSegmenter data with the Gentle transcript, remembering our 1TR offset from above.

# %%
# Assuming seg_df is your pandas DataFrame from inaSpeechSegmenter containing the 'music' labels
TARGET_TRS = 1040

# Initialize our array
tr_labels = np.full(TARGET_TRS, "silence", dtype=object)

for i in range(TARGET_TRS):
    # TR 0 is silence (scanner starting)
    if i == 0:
        continue

    # 1 TR offset from earlier
    tr_audio_start = (i - 1) * TR
    tr_audio_end = tr_audio_start + TR
    
    is_speech = False
    is_music = False
    
    # Check Gentle for Speech, if any word falls in this TR
    for word in valid_speech_words:
        if word['start'] < tr_audio_end and word['end'] > tr_audio_start:
            is_speech = True
            break
            
    # Check inaSpeechSegmenter for Music
    for _, row in seg_df.iterrows():
        if row['label'] == 'music':
            if row['start'] < tr_audio_end and row['end'] > tr_audio_start:
                is_music = True
                break
                
    # Assign the categorical tag
    if is_speech and is_music:
        tr_labels[i] = "speech_music"
    elif is_speech:
        tr_labels[i] = "speech"
    elif is_music:
        tr_labels[i] = "music"

# Add it to the feature matrix we built in the previous steps
aligned_features['category'] = tr_labels

# Create the binary indicator columns for your machine learning models
category_dummies = pd.get_dummies(aligned_features['category'], prefix='cat')
aligned_features = pd.concat([aligned_features, category_dummies], axis=1)

# Save the absolute final, ready-to-analyze matrix
final_matrix_path = os.path.join(dir_out, "tunnel_feature_matrix_final.csv")
aligned_features.to_csv(final_matrix_path, index=False)

print("Categorical tagging complete. Final matrix shape:", aligned_features.shape)
print(aligned_features[['tr_index', 'category', 'cat_speech', 'cat_music', 'cat_speech_music']].head(15))
# Out:
# Categorical tagging complete. Final matrix shape: (1040, 23)
#     tr_index      category  cat_speech  cat_music  cat_speech_music
# 0          0       silence       False      False             False
# 1          1        speech        True      False             False
# 2          2        speech        True      False             False
# 3          3        speech        True      False             False
# 4          4         music       False       True             False
# 5          5         music       False       True             False
# 6          6         music       False       True             False
# 7          7         music       False       True             False
# 8          8         music       False       True             False
# 9          9  speech_music       False      False              True
# 10        10        speech        True      False             False
# 11        11        speech        True      False             False
# 12        12        speech        True      False             False
# 13        13        speech        True      False             False
# 14        14        speech        True      False             False

# %% [markdown]
# # SCRIPT FOR SAVING FILES

# %%
# ---------------------------------------------------------
# 1. Save the Final Feature Matrix
# ---------------------------------------------------------
# We will save one final copy directly to your current working directory
aligned_features.to_csv("FINAL_tunnel_feature_matrix_1040TR.csv", index=False)
print("Saved final feature matrix.")

# ---------------------------------------------------------
# 2. Save the inaSpeechSegmenter Output
# ---------------------------------------------------------
# This locks in that 20-minute inference run!
seg_df.to_csv("segmenter_music_tags_raw.csv", index=False)
print("Saved raw inaSpeechSegmenter tags.")

# ---------------------------------------------------------
# 3. Save the Cleaned Gentle Speech Words
# ---------------------------------------------------------
# valid_speech_words is currently a list of dictionaries. 
# We easily convert it to a DataFrame to save it as a flat CSV.
speech_df = pd.DataFrame(valid_speech_words)

# We can drop the bulky 'phones' column if you don't need phonetic-level 
# alignment later, to keep the CSV clean and easy to read.
if 'phones' in speech_df.columns:
    speech_df = speech_df.drop(columns=['phones'])

speech_df.to_csv("gentle_speech_tags_clean.csv", index=False)
print("Saved cleaned Gentle speech tags.")

print("\nAll intermediate states successfully backed up to the current directory!")
# Out:
# Saved final feature matrix.
# Saved raw inaSpeechSegmenter tags.
# Saved cleaned Gentle speech tags.
#
# All intermediate states successfully backed up to the current directory!

# %% [markdown]
# MISC/FOR LATER:

# %%
# SAFE FMRI LOADING, SUBJECT EXCLUSION
import glob

# Grab all subject files for the tunnel task
all_subjects = glob.glob(os.path.join(data_dir, "*task-tunnel*.nii.gz"))

# Exclude the flagged subjects
excluded_subjects = ['sub-004', 'sub-013']
valid_subjects = [sub for sub in all_subjects if not any(excl in sub for excl in excluded_subjects)]

print(f"Found {len(valid_subjects)} valid subjects for analysis.")
